# %%
def dfs(graph, v, visited):
    #현재 반문한 노드 방문으로 표시
    visited[v] = True
    print(v, ' ')
    
    for i in graph:
        if not visited[i]:
            dfs(graph, i, visited) 
                     


visited = [False] * 9

graph = [[],
         [2,3,8],
         [1,7],
         [1,4],
         [3,5],
         [3,4],
         [7],
         [2,6,8],
         [1,7]
]

dfs(graph, 1, visited)
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 28
#      15 visited = [False] * 9
#      17 graph = [[],
#      18          [2,3,8],
#      19          [1,7],
#    (...)     25          [1,7]
#      26 ]
# ---> 28 dfs(graph, 1, visited)
#
# Cell In[1], line 7, in dfs(graph, v, visited)
#       4 print(v, ' ')
#       6 for i in graph:
# ----> 7     if not visited[i]:
#       8         dfs(graph, i, visited)
#
# TypeError: list indices must be integers or slices, not list
