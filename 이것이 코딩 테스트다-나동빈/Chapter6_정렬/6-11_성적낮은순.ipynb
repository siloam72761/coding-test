# %%
N = int(input())

dict_score = {}

for i in range(N):
    name, score = input().split()
    dict_score[name] = int(score)

sorted_scores = sorted(dict_score.items(), key = lambda x : x[1])

for student in sorted_scores:
    print(student[0], end = ' ')
# Out:
#  2
#  이순신 95
#  홍길동 90
# 홍길동 이순신
