# %%
N = int(input())
arr = []

for i in range(N):
    arr.append(int(input()))

arr.sort(reverse=True)

#더 좋은 방법 for i in arr:
for i in range(N):   
    print(arr[i], end = ' ')
# Out:
#  3
#  15
#  27
#  12
# 27 15 12
