# %%
def dfs(start, depth):
   # visited[start] = True
    
    if depth == M:
        print(' '.join(map(str, path)))
        return

    for i in range(start, N+1):
        path.append(i)
        dfs(i, depth+1)
        path.pop()
            

N,M = map(int, input().split())

path = []
#visited = [False] * (N+1)
dfs(1, 0)
# Out:
#  4 2
# 1 1
# 1 2
# 1 3
# 1 4
# 2 2
# 2 3
# 2 4
# 3 3
# 3 4
# 4 4
